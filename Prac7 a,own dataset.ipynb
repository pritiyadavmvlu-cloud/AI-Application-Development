# %%
import pandas as pd
df=pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 1. Display the Dataset
print("First 5 Rows:\n", df.head())
# 2. Check Dataset Information
print("\nDataset Info:")
print(df.info())
# 3. Display Dataset Shape
print("\nShape:", df.shape)
# 4. Display Column Names
print("\nColumns:", df.columns)
# 5. Display Summary Statistics
print("\nSummary Statistics:\n", df.describe())
# 6. Check Data Types
print("\nData Types:\n", df.dtypes)
# 7. Check Missing Values
print("\nMissing Values:\n", df.isnull().sum())
# 8. Handle Missing Values
df.fillna(df.mean(numeric_only=True), inplace=True)
# 9. Remove Duplicate Records
df.drop_duplicates(inplace=True)
# Out:
# First 5 Rows:
#     SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0          5.1         3.5           1.4          0.2        0         7.0
# 1          4.9         3.0           1.4          0.2        0         7.0
# 2          4.7         3.2           1.3          0.2        0         6.5
# 3          4.6         3.1           1.5          0.2        0         7.5
# 4          5.0         3.6           1.4          0.2        0         7.0
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# Index: 147 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SepalLength   147 non-null    float64
#  1   SepalWidth    147 non-null    float64
#  2   petal_length  147 non-null    float64
#  3   petal_width   147 non-null    float64
#  4   species       147 non-null    int64
#  5   PetalRatio    147 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 8.0 KB
# None
#
# Shape: (147, 6)
#
# Columns: Index(['SepalLength', 'SepalWidth', 'petal_length', 'petal_width', 'species',
#        'PetalRatio'],
#       dtype='str')
#
# Summary Statistics:
#         SepalLength  SepalWidth  petal_length  petal_width     species  \
# count   147.000000  147.000000    147.000000   147.000000  147.000000
# mean      5.856463    3.055782      3.780272     1.208844    1.006803
# std       0.829100    0.437009      1.759111     0.757874    0.815069
# min       4.300000    2.000000      1.000000     0.100000    0.000000
# 25%       5.100000    2.800000      1.600000     0.300000    0.000000
# 50%       5.800000    3.000000      4.400000     1.300000    1.000000
# 75%       6.400000    3.300000      5.100000     1.800000    2.000000
# max       7.900000    4.400000      6.900000     2.500000    2.000000
#
#        PetalRatio
# count  147.000000
# mean     4.233951
# std      2.364098
# min      2.125000
# 25%      2.804762
# 50%      3.300000
# 75%      4.666667
# max     15.000000
#
# Data Types:
#  SepalLength     float64
# SepalWidth      float64
# petal_length    float64
# petal_width     float64
# species           int64
# PetalRatio      float64
# dtype: object
#
# Missing Values:
#  SepalLength     0
# SepalWidth      0
# petal_length    0
# petal_width     0
# species         0
# PetalRatio      0
# dtype: int64

# %%
# 11. Encode Categorical Data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 12. Rename Columns
df.rename(columns={
    'sepal_length': 'SepalLength',
    'sepal_width': 'SepalWidth'
}, inplace=True)
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 13. Drop Unnecessary Columns
# (No unnecessary column in Iris dataset)
# 15. Create New Features (DO THIS BEFORE SELECTING X)
df['PetalRatio'] = df['petal_length'] / df['petal_width']
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 16. Convert Data Types
df['SepalLength'] = df['SepalLength'].astype(float)
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 18. Standardize Data
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_standardized = std.fit_transform(X)
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 19. Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_standardized, y, test_size=0.2, random_state=42
)
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 20. Train Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
print(df)
# Out:
#      SepalLength  SepalWidth  petal_length  petal_width  species  PetalRatio
# 0            5.1         3.5           1.4          0.2        0    7.000000
# 1            4.9         3.0           1.4          0.2        0    7.000000
# 2            4.7         3.2           1.3          0.2        0    6.500000
# 3            4.6         3.1           1.5          0.2        0    7.500000
# 4            5.0         3.6           1.4          0.2        0    7.000000
# ..           ...         ...           ...          ...      ...         ...
# 145          6.7         3.0           5.2          2.3        2    2.260870
# 146          6.3         2.5           5.0          1.9        2    2.631579
# 147          6.5         3.0           5.2          2.0        2    2.600000
# 148          6.2         3.4           5.4          2.3        2    2.347826
# 149          5.9         3.0           5.1          1.8        2    2.833333
#
# [147 rows x 6 columns]

# %%
# 21. Accuracy
from sklearn.metrics import accuracy_score
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
print("\nTraining Accuracy:", accuracy_score(y_train, y_pred_train))
print("Testing Accuracy:", accuracy_score(y_test, y_pred_test))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.9666666666666667

# %% [markdown]
# real life business dataset:supermarket_sales.csv

# %%
import pandas as pd
df = pd.read_csv("supermarket_sales.csv")
print(df.head())
# Out:
#   Invoice_ID Branch    City Customer_Type  Gender Product_Line  Unit_Price  \
# 0    INV1000      C  Mumbai        Normal    Male  Electronics       59.03
# 1    INV1001      A   Delhi        Normal    Male       Sports      194.94
# 2    INV1002      C  Mumbai        Normal    Male         Food      145.15
# 3    INV1003      C   Delhi        Normal  Female  Electronics      197.37
# 4    INV1004      A   Delhi        Member  Female         Food      103.89
#
#    Quantity  Tax_5%   Total   Payment  Rating
# 0         2   37.95  391.25      Cash     4.6
# 1         5   41.30  539.78  E-wallet     9.8
# 2         1   34.65  793.37      Cash     8.4
# 3         7   36.15  714.97      Cash     5.7
# 4         1   43.21  501.31      Cash     2.1

# %%
# Check missing values
print(df.isnull().sum())
print(df)
# Handle missing values
df.ffill(inplace=True)
print(df)
# Encode categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_columns = [
    'Branch',
    'City',
    'Customer_Type',
    'Gender',
    'Product_Line',
    'Payment'
]
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])
print(df)
# Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = [
    'Unit_Price',
    'Quantity',
    'Tax_5%',
    'Total',
    'Branch',
    'City',
    'Customer_Type',
    'Gender',
    'Product_Line',
    'Payment'
]
X = df[features]
X_scaled = scaler.fit_transform(X)
print(df)
# Out:
# Invoice_ID         0
# Branch             0
# City               0
# Customer_Type      0
# Gender             0
# Product_Line       0
# Unit_Price         0
# Quantity           0
# Tax_5%             0
# Total              0
# Payment            0
# Rating             0
# Rating_Category    0
# dtype: int64
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
y = np.where(df['Rating'] >= 5, 1, 0)
# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)
print(df)
# Out:
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
# Create model
model = DecisionTreeClassifier(random_state=42)
# Train model
model.fit(X_train, y_train)
print(df)
# Out:
#     Invoice_ID  Branch  City  Customer_Type  Gender  Product_Line  Unit_Price  \
# 0      INV1000       2     2              1       1             1       59.03
# 1      INV1001       0     1              1       1             4      194.94
# 2      INV1002       2     2              1       1             2      145.15
# 3      INV1003       2     1              1       0             1      197.37
# 4      INV1004       0     1              0       0             2      103.89
# ..         ...     ...   ...            ...     ...           ...         ...
# 195    INV1195       1     1              0       1             2      238.52
# 196    INV1196       2     1              1       1             2      461.68
# 197    INV1197       2     0              1       1             1      213.08
# 198    INV1198       1     0              0       0             4      311.26
# 199    INV1199       0     0              1       1             3      334.52
#
#      Quantity  Tax_5%   Total  Payment  Rating  Rating_Category
# 0           2   37.95  391.25        0     4.6                0
# 1           5   41.30  539.78        2     9.8                1
# 2           1   34.65  793.37        0     8.4                1
# 3           7   36.15  714.97        0     5.7                1
# 4           1   43.21  501.31        0     2.1                0
# ..        ...     ...     ...      ...     ...              ...
# 195         9   38.73  655.43        2     3.1                0
# 196         7   10.85  736.10        2     3.1                0
# 197         1   39.12  250.34        1     3.0                0
# 198         8    6.11  250.86        1     2.6                0
# 199         3    6.00  133.00        1     6.9                1
#
# [200 rows x 13 columns]

# %%
from sklearn.metrics import accuracy_score
# Prediction
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Accuracy calculation
training_accuracy = accuracy_score(
    y_train,
    y_train_pred
)
testing_accuracy = accuracy_score(
    y_test,
    y_test_pred
)
print("Training Accuracy:", training_accuracy)
print("Testing Accuracy:", testing_accuracy)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.425

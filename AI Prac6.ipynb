# %%
# Bayesian Network using pgmpy
# Example: Burglary-Alarm Network

from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# Step 1: Create Bayesian Network structure
model = DiscreteBayesianNetwork([
    ("Burglary", "Alarm"),
    ("Earthquake", "Alarm"),
    ("Alarm", "JohnCalls"),
    ("Alarm", "MaryCalls")
])

# Step 2: Define Conditional Probability Tables

# P(Burglary)
cpd_burglary = TabularCPD(
    variable="Burglary",
    variable_card=2,
    values=[[0.999], [0.001]],
    state_names={"Burglary": ["False", "True"]}
)

# P(Earthquake)
cpd_earthquake = TabularCPD(
    variable="Earthquake",
    variable_card=2,
    values=[[0.998], [0.002]],
    state_names={"Earthquake": ["False", "True"]}
)

# P(Alarm | Burglary, Earthquake)
cpd_alarm = TabularCPD(
    variable="Alarm",
    variable_card=2,
    values=[
        [0.999, 0.71, 0.06, 0.05],  # Alarm = False
        [0.001, 0.29, 0.94, 0.95]   # Alarm = True
    ],
    evidence=["Burglary", "Earthquake"],
    evidence_card=[2, 2],
    state_names={
        "Alarm": ["False", "True"],
        "Burglary": ["False", "True"],
        "Earthquake": ["False", "True"]
    }
)

# P(JohnCalls | Alarm)
cpd_john = TabularCPD(
    variable="JohnCalls",
    variable_card=2,
    values=[
        [0.95, 0.10],  # JohnCalls = False
        [0.05, 0.90]   # JohnCalls = True
    ],
    evidence=["Alarm"],
    evidence_card=[2],
    state_names={
        "JohnCalls": ["False", "True"],
        "Alarm": ["False", "True"]
    }
)

# P(MaryCalls | Alarm)
cpd_mary = TabularCPD(
    variable="MaryCalls",
    variable_card=2,
    values=[
        [0.99, 0.30],  # MaryCalls = False
        [0.01, 0.70]   # MaryCalls = True
    ],
    evidence=["Alarm"],
    evidence_card=[2],
    state_names={
        "MaryCalls": ["False", "True"],
        "Alarm": ["False", "True"]
    }
)

# Step 3: Add CPDs to model
model.add_cpds(
    cpd_burglary,
    cpd_earthquake,
    cpd_alarm,
    cpd_john,
    cpd_mary
)

# Step 4: Check model correctness
print("Is Bayesian Network valid?", model.check_model())

# Step 5: Perform inference
inference = VariableElimination(model)

# Query: Probability of Burglary when John and Mary both call
result = inference.query(
    variables=["Burglary"],
    evidence={
        "JohnCalls": "True",
        "MaryCalls": "True"
    }
)

print("\nProbability of Burglary given JohnCalls=True and MaryCalls=True:")
print("Priti Yadav T054")
print(result)
# Out:
# Is Bayesian Network valid? True
#
# Probability of Burglary given JohnCalls=True and MaryCalls=True:
# Priti Yadav T054
# +-----------------+-----------------+
# | Burglary        |   phi(Burglary) |
# +=================+=================+
# | Burglary(False) |          0.7158 |
# +-----------------+-----------------+
# | Burglary(True)  |          0.2842 |
# +-----------------+-----------------+

# %% [markdown]
# Credit Card Fraud Detection – Bayesian Network

# %%
# Bayesian Network using pgmpy
# Example: Credit Card Fraud Detection

from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# Step 1: Create Bayesian Network structure
model = DiscreteBayesianNetwork([
    ("TransactionAmount", "Fraud"),
    ("LocationChange", "Fraud")
])

# Step 2: Define Conditional Probability Tables

# P(TransactionAmount)
cpd_amount = TabularCPD(
    variable="TransactionAmount",
    variable_card=2,
    values=[[0.8], [0.2]],
    state_names={"TransactionAmount": ["Low", "High"]}
)

# P(LocationChange)
cpd_location = TabularCPD(
    variable="LocationChange",
    variable_card=2,
    values=[[0.9], [0.1]],
    state_names={"LocationChange": ["No", "Yes"]}
)

# P(Fraud | TransactionAmount, LocationChange)
cpd_fraud = TabularCPD(
    variable="Fraud",
    variable_card=2,
    values=[
        [0.99, 0.80, 0.70, 0.10],  # Fraud = False
        [0.01, 0.20, 0.30, 0.90]   # Fraud = True
    ],
    evidence=["TransactionAmount", "LocationChange"],
    evidence_card=[2, 2],
    state_names={
        "Fraud": ["False", "True"],
        "TransactionAmount": ["Low", "High"],
        "LocationChange": ["No", "Yes"]
    }
)

# Step 3: Add CPDs to model
model.add_cpds(
    cpd_amount,
    cpd_location,
    cpd_fraud
)

# Step 4: Check model correctness
print("Is Bayesian Network valid?", model.check_model())

# Step 5: Perform inference
inference = VariableElimination(model)

# Query: Probability of Fraud when
# Transaction Amount is High and Location has Changed
result = inference.query(
    variables=["Fraud"],
    evidence={
        "TransactionAmount": "High",
        "LocationChange": "Yes"
    }
)

print("\nProbability of Fraud given High Amount and Location Change:")
print("Priti Yadav T054")
print(result)
# Out:
# Is Bayesian Network valid? True
#
# Probability of Fraud given High Amount and Location Change:
# Priti Yadav T054
# +--------------+--------------+
# | Fraud        |   phi(Fraud) |
# +==============+==============+
# | Fraud(False) |       0.1000 |
# +--------------+--------------+
# | Fraud(True)  |       0.9000 |
# +--------------+--------------+

# %%
# Posterior Probability using Bayesian Network
# Query: P(Burglary | Alarm = True)

from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# Step 1: Create Bayesian Network structure
model = DiscreteBayesianNetwork([
    ("Burglary", "Alarm"),
    ("Earthquake", "Alarm")
])

# Step 2: Define probability of Burglary
cpd_burglary = TabularCPD(
    variable="Burglary",
    variable_card=2,
    values=[[0.999], [0.001]],
    state_names={"Burglary": ["False", "True"]}
)

# Step 3: Define probability of Earthquake
cpd_earthquake = TabularCPD(
    variable="Earthquake",
    variable_card=2,
    values=[[0.998], [0.002]],
    state_names={"Earthquake": ["False", "True"]}
)

# Step 4: Define probability of Alarm
# P(Alarm | Burglary, Earthquake)

cpd_alarm = TabularCPD(
    variable="Alarm",
    variable_card=2,
    values=[
        [0.999, 0.71, 0.06, 0.05],  # Alarm = False
        [0.001, 0.29, 0.94, 0.95]   # Alarm = True
    ],
    evidence=["Burglary", "Earthquake"],
    evidence_card=[2, 2],
    state_names={
        "Alarm": ["False", "True"],
        "Burglary": ["False", "True"],
        "Earthquake": ["False", "True"]
    }
)

# Step 5: Add CPDs to model
model.add_cpds(
    cpd_burglary,
    cpd_earthquake,
    cpd_alarm
)

# Step 6: Check whether model is correct
print("Is Bayesian Network valid?", model.check_model())

# Step 7: Perform inference
inference = VariableElimination(model)

result = inference.query(
    variables=["Burglary"],
    evidence={"Alarm": "True"}
)

print("\nPosterior Probability:")
print("P(Burglary | Alarm = True)")
print("Priti Yadav T054")
print(result)
# Out:
# Is Bayesian Network valid? True
#
# Posterior Probability:
# P(Burglary | Alarm = True)
# Priti Yadav T054
# +-----------------+-----------------+
# | Burglary        |   phi(Burglary) |
# +=================+=================+
# | Burglary(False) |          0.6264 |
# +-----------------+-----------------+
# | Burglary(True)  |          0.3736 |
# +-----------------+-----------------+

# %%
# Posterior Probability using Bayesian Network
# Query: P(Fraud | TransactionAmount = High, LocationChange = Yes)

from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# Step 1: Create Bayesian Network structure
model = DiscreteBayesianNetwork([
    ("TransactionAmount", "Fraud"),
    ("LocationChange", "Fraud")
])

# Step 2: Define probability of Transaction Amount
cpd_amount = TabularCPD(
    variable="TransactionAmount",
    variable_card=2,
    values=[[0.8], [0.2]],
    state_names={"TransactionAmount": ["Low", "High"]}
)

# Step 3: Define probability of Location Change
cpd_location = TabularCPD(
    variable="LocationChange",
    variable_card=2,
    values=[[0.9], [0.1]],
    state_names={"LocationChange": ["No", "Yes"]}
)

# Step 4: Define probability of Fraud
# P(Fraud | TransactionAmount, LocationChange)

cpd_fraud = TabularCPD(
    variable="Fraud",
    variable_card=2,
    values=[
        [0.99, 0.80, 0.70, 0.10],  # Fraud = False
        [0.01, 0.20, 0.30, 0.90]   # Fraud = True
    ],
    evidence=["TransactionAmount", "LocationChange"],
    evidence_card=[2, 2],
    state_names={
        "Fraud": ["False", "True"],
        "TransactionAmount": ["Low", "High"],
        "LocationChange": ["No", "Yes"]
    }
)

# Step 5: Add CPDs to model
model.add_cpds(
    cpd_amount,
    cpd_location,
    cpd_fraud
)

# Step 6: Check whether model is correct
print("Is Bayesian Network valid?", model.check_model())

# Step 7: Perform inference
inference = VariableElimination(model)

result = inference.query(
    variables=["Fraud"],
    evidence={
        "TransactionAmount": "High",
        "LocationChange": "Yes"
    }
)

print("\nPosterior Probability:")
print("P(Fraud | TransactionAmount = High, LocationChange = Yes)")
print("Priti Yadav T054")
print(result)
# Out:
# Is Bayesian Network valid? True
#
# Posterior Probability:
# P(Fraud | TransactionAmount = High, LocationChange = Yes)
# Priti Yadav T054
# +--------------+--------------+
# | Fraud        |   phi(Fraud) |
# +==============+==============+
# | Fraud(False) |       0.1000 |
# +--------------+--------------+
# | Fraud(True)  |       0.9000 |
# +--------------+--------------+
